# %% [markdown]
# <a href="https://colab.research.google.com/github/athil1116/Athil/blob/main/movEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/movies_cleaned.csv')
df
# Out:
#            1                     The Nightmare Before Christmas    1993  3.9  \
# 0          2                                          The Mummy  1932.0  3.5
# 1          3                               Orphans of the Storm  1921.0  3.2
# 2          4                               The Object of Beauty  1991.0  2.8
# 3          5                                         Night Tide  1963.0  2.8
# 4          6                                One Magic Christmas  1985.0  3.8
# ...      ...                                                ...     ...  ...
# 18044  18046  The Country Mouse and the City Mouse Adventure...  1998.0  3.4
# 18045  18047                              Lost: Season 6: Recon  2010.0  3.4
# 18046  18048  The Country Mouse and the City Mouse Adventure...  1998.0  3.4
# 18047  18049                          Lost: Season 6: Dr. Linus  2010.0  3.4
# 18048  18050                                     The Country Mo     NaN  NaN
#
#        4568.0
# 0      4388.0
# ...

# %% [markdown]
# Give column name as Id, Movie, Year, Rating, Duration

# %%
df=pd.read_csv('/content/movies_cleaned.csv',names=['id','Movie','Year','Rating','Duration'])
df
# Out:
#           id                                              Movie    Year  \
# 0          1                     The Nightmare Before Christmas  1993.0
# 1          2                                          The Mummy  1932.0
# 2          3                               Orphans of the Storm  1921.0
# 3          4                               The Object of Beauty  1991.0
# 4          5                                         Night Tide  1963.0
# ...      ...                                                ...     ...
# 18045  18046  The Country Mouse and the City Mouse Adventure...  1998.0
# 18046  18047                              Lost: Season 6: Recon  2010.0
# 18047  18048  The Country Mouse and the City Mouse Adventure...  1998.0
# 18048  18049                          Lost: Season 6: Dr. Linus  2010.0
# 18049  18050                                     The Country Mo     NaN
#
#        Rating  Duration
# 0         3.9    4568.0
# 1         3.5    4388.0
# 2         3.2    9062.0
# ...

# %% [markdown]
# Display the number of rows and number of columns

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 18050
# Number of columns: 5

# %% [markdown]
# Display the five observations that have highest duration

# %%
df.sort_values(by='Duration').tail(5)
# Out:
#           id                    Movie    Year  Rating  Duration
# 92        93            Heaven's Gate  1980.0     3.0   13143.0
# 1831    1832  Dr. Mabuse: The Gambler  1922.0     3.1   16422.0
# 2423    2424        The Best of Youth  2003.0     3.9   22024.0
# 12303  12304    Example 8 Hour 23.976  2010.0     3.2   28813.0
# 18049  18050           The Country Mo     NaN     NaN       NaN

# %% [markdown]
# Remove if any duplicate exists and change the index accordingly

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#           id                                              Movie    Year  \
# 0          1                     The Nightmare Before Christmas  1993.0
# 1          2                                          The Mummy  1932.0
# 2          3                               Orphans of the Storm  1921.0
# 3          4                               The Object of Beauty  1991.0
# 4          5                                         Night Tide  1963.0
# ...      ...                                                ...     ...
# 18045  18046  The Country Mouse and the City Mouse Adventure...  1998.0
# 18046  18047                              Lost: Season 6: Recon  2010.0
# 18047  18048  The Country Mouse and the City Mouse Adventure...  1998.0
# 18048  18049                          Lost: Season 6: Dr. Linus  2010.0
# 18049  18050                                     The Country Mo     NaN
#
#        Rating  Duration
# 0         3.9    4568.0
# 1         3.5    4388.0
# 2         3.2    9062.0
# ...

# %% [markdown]
# Rename the column name ‘Movie’ as Film

# %%
df.rename(columns={'Movie':'Film'},inplace=True)
df
# Out:
#           id                                               Film    Year  \
# 0          1                     The Nightmare Before Christmas  1993.0
# 1          2                                          The Mummy  1932.0
# 2          3                               Orphans of the Storm  1921.0
# 3          4                               The Object of Beauty  1991.0
# 4          5                                         Night Tide  1963.0
# ...      ...                                                ...     ...
# 18045  18046  The Country Mouse and the City Mouse Adventure...  1998.0
# 18046  18047                              Lost: Season 6: Recon  2010.0
# 18047  18048  The Country Mouse and the City Mouse Adventure...  1998.0
# 18048  18049                          Lost: Season 6: Dr. Linus  2010.0
# 18049  18050                                     The Country Mo     NaN
#
#        Rating  Duration
# 0         3.9    4568.0
# 1         3.5    4388.0
# 2         3.2    9062.0
# ...

# %% [markdown]
# Display all the observation starting from index 100 upto 200

# %%
df.iloc[100:200]
# Out:
#       id                                              Film    Year  Rating  \
# 100  101                       The Hunchback of Notre Dame  1923.0     3.5
# 101  102                                          Heathers  1989.0     3.7
# 102  103                                Godzilla's Revenge  1969.0     3.3
# 103  104                                       Hard Target  1993.0     3.4
# 104  105                Henry: Portrait of a Serial Killer  1986.0     3.2
# ..   ...                                               ...     ...     ...
# 195  196                            Tremors 2: Aftershocks  1995.0     3.3
# 196  197                                 The Toxic Avenger  1985.0     3.0
# 197  198                                     The Two Jakes  1990.0     3.1
# 198  199  Tales from the Crypt Presents: Bordello of Blood  1996.0     3.3
# 199  200                               Tales from the Hood  1995.0     3.4
#
#      Duration
# 100    6750.0
# 101    6193.0
# 102    4165.0
# ...

# %% [markdown]
# .Display the name and releasing year of the film with maximum duration

# %%
df.sort_values(by='Duration',ascending=False)[['Film','Year','Duration']].head(1)
# Out:
#                         Film    Year  Duration
# 12303  Example 8 Hour 23.976  2010.0   28813.0

# %% [markdown]
# .Display the count of films released in each year.

# %%
df.groupby('Year').size().reset_index(name='Count')
# Out:
#       Year  Count
# 0   1913.0      1
# 1   1914.0      1
# 2   1915.0      1
# 3   1916.0      1
# 4   1919.0      1
# ..     ...    ...
# 94  2009.0   1688
# 95  2010.0    850
# 96  2011.0     89
# 97  2012.0     39
# 98  2013.0      3
#
# [99 rows x 2 columns]

# %% [markdown]
# .Find the film released between 1986-1996 having highest duration

# %%
df.loc[(df['Year']>=1986) & (df['Year']<=1996)].sort_values(by='Duration',ascending=False)[['Film','Year','Duration']].head(1)
# Out:
#                              Film    Year  Duration
# 1648  Dilwale Dulhania Le Jayenge  1995.0   11390.0

# %% [markdown]
# Find the films having duration greater than 7000 and rating above 3.5

# %%
df.loc[(df['Duration']>7000) & (df['Rating']>3.5)]
# Out:
#           id                                               Film    Year  \
# 13        14                               The Boys from Brazil  1978.0
# 35        36                                     Into the Woods  1990.0
# 41        42                          In the Name of the Father  1993.0
# 43        44                                 Do the Right Thing  1989.0
# 54        55                                          The Doors  1991.0
# ...      ...                                                ...     ...
# 16065  16066  Detective Dee and the Mystery of the Phantom F...  2010.0
# 16067  16068                                         Aftershock  2010.0
# 16085  16086                     Transformers: Dark of the Moon  2011.0
# 16087  16088                 Captain America: The First Avenger  2011.0
# 17615  17616                                   A Barefoot Dream  2010.0
#
#        Rating  Duration
# 13        3.6    7417.0
# 35        4.0    9077.0
# 41        3.9    7972.0
# ...

# %% [markdown]
# Print the details about 5 films having less rating , display in the descending order

# %%
df.sort_values(by='Rating').head(5)
# Out:
#           id                Film    Year  Rating  Duration
# 3368    3369        Mummy Maniac  2007.0     1.8    4815.0
# 15641  15642  Clear Blue Tuesday  2009.0     1.8    6392.0
# 13637  13638            Love 600  1970.0     1.8    5429.0
# 13505  13506         Hammer Down  1992.0     1.8    5032.0
# 16343  16344          Sandcastle  2010.0     1.8    5465.0

# %% [markdown]
# Print the name of the film released in 1996 have highest rating

# %%
df.sort_values(by='Rating',ascending=False).loc[df['Year']==1996][['Film','Year','Rating']].head(1)
# Out:
#                           Film    Year  Rating
# 14815  Big Cat Diary: Season 1  1996.0     4.1
